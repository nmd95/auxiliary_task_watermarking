# %%
# %cd /content/drive/MyDrive/amnlp_project_round_2
# Out:
# /content/drive/MyDrive/amnlp_project_round_2

# %%
# !pip install transformers
# !pip install datasets

# %%
base_path = "/content/drive/MyDrive/amnlp_project_round_2/seed_models/model_0.bin"
destination_dir_path = "/content/drive/MyDrive/amnlp_project_round_2/ft_topy_trials"
epochs = 5
lr = 2e-5
batch_size = 16

# %%
# !python sentiment_ft.py "/content/drive/MyDrive/amnlp_project_round_2/seed_models/model_0.bin" "/content/drive/MyDrive/amnlp_project_round_2/ft_topy_trials" 5 2e-5 16 'bert-base-uncased'
# Out:
# 2021-07-07 17:56:57.073785: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Reusing dataset glue (/root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
# Loading cached processed dataset at /root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-6706aaf0cc82abbe.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-3bb55e010ddc6695.arrow
# Loading cached processed dataset at /root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad/cache-d675c6a4f8a78a89.arrow
